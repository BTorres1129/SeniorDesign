# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Brandon\Desktop\Time Study Data Frames\EyeTrackingData(10.22-10.28).csv", index_col=0)
df = df.iloc[18:30,0:4]
df
#The output below show all of the raw data that will be interpreting for generating a heirarchical clustering heatmap:
# Out:
#         User #3  User #4  User #7  User #8  User #11  User #12  User #15  \
# Task #
# 1        232.52   181.24    93.96   128.21    159.50    102.86     90.99
# 2a        37.58    36.93    28.66    25.32     25.51     40.12     20.29
# 2b        15.95    31.44    25.37    11.40     20.02     28.72     12.47
# 2c        25.20    26.17    30.43    31.46     14.80     14.82     11.04
# 2d        86.93    85.13    52.48    69.42     52.97     32.42     50.42
# 2e        48.79    38.49    42.51    53.15     45.15     46.10     47.79
# 2f        14.35    11.49    24.94    25.66     25.98     15.42     12.25
# 2g         5.07     9.61    11.48    16.21     19.83     13.10      9.38
# 2h        12.82    14.63    29.62    19.83     12.92     22.25     22.58
# 2i       174.50   134.85    83.73    74.18    118.47    162.42     80.00
# 2j        78.93   158.67    70.76    98.10    150.40    121.40     73.23
# 2k        41.08    47.36    32.82    59.28     23.19     50.84     38.81
# 2l        20.38    10.88    18.02    13.69     25.77     28.17     16.51
# 3         23.89    58.52    26.70    31.81     24.37     56.58     42.45
#
#         User #16
# Task #
# 1         262.83
# 2a         15.25
# 2b         17.85
# 2c         11.38
# 2d         53.07
# 2e         38.30
# 2f         28.90
# 2g          4.30
# 2h         10.28
# 2i         68.80
# 2j        118.64
# 2k         23.07
# 2l         12.61
# 3          56.47

# %%
lst = list(df.columns)
for x in range(len(lst)):
    df[lst[x]] = pd.to_numeric(df[lst[x]], downcast="float")
df
#The same as the previous output but datframe has been converted to float decimals:
# Out:
#            User #3     User #4    User #7     User #8    User #11    User #12  \
# Task #
# 1       232.520004  181.240005  93.959999  128.210007  159.500000  102.860001
# 2a       37.580002   36.930000  28.660000   25.320000   25.510000   40.119999
# 2b       15.950000   31.440001  25.370001   11.400000   20.020000   28.719999
# 2c       25.200001   26.170000  30.430000   31.459999   14.800000   14.820000
# 2d       86.930000   85.129997  52.480000   69.419998   52.970001   32.419998
# 2e       48.790001   38.490002  42.509998   53.150002   45.150002   46.099998
# 2f       14.350000   11.490000  24.940001   25.660000   25.980000   15.420000
# 2g        5.070000    9.610000  11.480000   16.209999   19.830000   13.100000
# 2h       12.820000   14.630000  29.620001   19.830000   12.920000   22.250000
# 2i      174.500000  134.850006  83.730003   74.180000  118.470001  162.419998
# 2j       78.930000  158.669998  70.760002   98.099998  150.399994  121.400002
# 2k       41.080002   47.360001  32.820000   59.279999   23.190001   50.840000
# 2l       20.379999   10.880000  18.020000   13.690000   25.770000   28.170000
# 3        23.889999   58.520000  26.700001   31.809999   24.370001   56.580002
#
#          User #15    User #16
# Task #
# 1       90.989998  262.829987
# 2a      20.290001   15.250000
# 2b      12.470000   17.850000
# 2c      11.040000   11.380000
# 2d      50.419998   53.070000
# 2e      47.790001   38.299999
# 2f      12.250000   28.900000
# 2g       9.380000    4.300000
# 2h      22.580000   10.280000
# 2i      80.000000   68.800003
# 2j      73.230003  118.639999
# 2k      38.810001   23.070000
# 2l      16.510000   12.610000
# 3       42.450001   56.470001

# %%
sns.clustermap(df, metric="sqeuclidean", standard_scale=1, cmap="coolwarm")
#This output is the raw generation of the maximized variance, Squared Euclidean distance heatmap:

# %%
sns.clustermap(df, metric="euclidean", standard_scale=1, method="ward", cmap="coolwarm")
#This output is the raw generation of the minimized variance heatmap:

# %%
sns.clustermap(df, z_score=1, cmap="coolwarm")
#This output is the raw generation of the normalized heatmap:
