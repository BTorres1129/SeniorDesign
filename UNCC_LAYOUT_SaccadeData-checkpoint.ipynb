# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Brandon\Desktop\SaccadeData.csv", index_col=0)
df = df.iloc[0:28,0:20]
df
#The output below show all of the raw data that will be interpreting for generating a heirarchical clustering heatmap:
# Out:
#                     User #1  User #2  User #3  User #4  User #5  User #6  \
# Saccade Transition
# A-B                       9        7       12       15       18       13
# A-C                      10        8        4        7        4       14
# A-D                       8        7        8        5        7        3
# A-E                       8        8        6        9       10        7
# A-F                       2        2        0        1        0        0
# A-G                       1        2        1        1        1        2
# A-H                       6        2        5        4        6        2
# B-C                      18       14       15        7        8       10
# B-D                       7        7       13        6        7        7
# B-E                       5        4        9        6        6        9
# B-F                       6        5        7        7        5        6
# B-G                       3        4        5        3        2        5
# B-H                       2        3        1        2        3        3
# C-D                       4        9       11        7       12       12
# C-E                       4        2        6        6        3        3
# C-F                       5        6        6       11       10        8
# C-G                       2        2        4        4        5        3
# C-H                       2        4        3        4        3        3
# D-E                       5        8        8        7        5        8
# D-F                       4        6        7        5        6        4
# D-G                       9        7        6        9       12        7
# D-H                       3        1        2        2        2        2
# E-F                      13       10       13        8       12       12
# E-G                       5        4        7        9        7        9
# E-H                       3        4        4        3        4        3
# F-G                       6        6        7       10        8        8
# F-H                       6        9        5        5        8        5
# G-H                      15       15       12       11        7        8
#
#                     User #7  User #8  User #9  User #10  User #11  User #12  \
# Saccade Transition
# A-B                      19       11       14         7        16        18
# A-C                       4       14       14        10         5        13
# A-D                       4        6        3         6         2         4
# A-E                       7       10        6         9         8         6
# A-F                       2        3        3         2         1         3
# A-G                       2        2        2         2         1         1
# A-H                       3        6        6         6         6         2
# B-C                      17        4        6        19         4        12
# B-D                      13       10        4         8         9        13
# B-E                       4        4        4         4         6         8
# B-F                       7        6        6         5         8         7
# B-G                       4        2        4         3         6         6
# B-H                       5        5        1         1         1         2
# C-D                       9       13        9         5         4         7
# C-E                       4        5        4         2         6         2
# C-F                       6        5        7        10        11         3
# C-G                       4        4        2         6         4         5
# C-H                       1        2        1         2         3         4
# D-E                       7        6        4         6         8         4
# D-F                       2        7        5         5         5         3
# D-G                      12       12        9         9         5        12
# D-H                       1        3        2         1         2         3
# E-F                      13       12        8        10        10         9
# E-G                      10        5        8         8        10         4
# E-H                       2        3        1         3         2         1
# F-G                       6        8       11         7         6         8
# F-H                       5        9        8         8         5         9
# G-H                      14       13       15         9         4        14
#
#                     User #13  User #14  User #15  User #16  User #17  \
# Saccade Transition
# A-B                       16        10         9        18        10
# A-C                       13         8         6         5        12
# A-D                        2         5         8         2         7
# A-E                        8        10         7         6         7
# A-F                        2         3         3         1         3
# A-G                        2         2         2         2         1
# A-H                        4         3         4         4         2
# B-C                       17        14        19         7         4
# B-D                        7        14         4        11         6
# B-E                        4         4         5         4         5
# B-F                        8         5         7         6         7
# B-G                        6         6         4         6         2
# B-H                        4         5         1         2         2
# C-D                        9         7        13        13        10
# C-E                        2         6         5         5         4
# C-F                       11        11         5        12         6
# C-G                        2         2         3         2         2
# C-H                        2         3         1         4         1
# D-E                        5         7         4         4         8
# D-F                        2         5         2         7         5
# D-G                        6        10        12         6         8
# D-H                        2         3         1         3         3
# E-F                        9        10        14        13         9
# E-G                       10         5         9         5         4
# E-H                        1         3         2         1         3
# F-G                        7         8        12        12        12
# F-H                        8         5        11         9        10
# G-H                       10        10        13        16         9
#
#                     User #18  User #19  User #20
# Saccade Transition
# A-B                       19         9        17
# A-C                        4         9        14
# A-D                        3         7         5
# A-E                       10         7         9
# A-F                        2         1         1
# A-G                        1         1         2
# A-H                        4         6         6
# B-C                       11        12         8
# B-D                       14         7        14
# B-E                        3         9         9
# B-F                        8         7         7
# B-G                        5         2         4
# B-H                        1         1         4
# C-D                        5         9        10
# C-E                        6         3         5
# C-F                       10         4         9
# C-G                        6         5         1
# C-H                        2         3         2
# D-E                        5         6         6
# D-F                        3         5         3
# D-G                        9        11         9
# D-H                        3         2         2
# E-F                       10         9        12
# E-G                        4         5         4
# E-H                        1         1         1
# F-G                        9         8        12
# F-H                       11        10         6
# G-H                        8        12         5

# %%
lst = list(df.columns)
for x in range(len(lst)):
    df[lst[x]] = pd.to_numeric(df[lst[x]], downcast="float")
df
#The same as the previous output but datframe has been converted to float decimals:
# Out:
#                     User #1  User #2  User #3  User #4  User #5  User #6  \
# Saccade Transition
# A-B                     9.0      7.0     12.0     15.0     18.0     13.0
# A-C                    10.0      8.0      4.0      7.0      4.0     14.0
# A-D                     8.0      7.0      8.0      5.0      7.0      3.0
# A-E                     8.0      8.0      6.0      9.0     10.0      7.0
# A-F                     2.0      2.0      0.0      1.0      0.0      0.0
# A-G                     1.0      2.0      1.0      1.0      1.0      2.0
# A-H                     6.0      2.0      5.0      4.0      6.0      2.0
# B-C                    18.0     14.0     15.0      7.0      8.0     10.0
# B-D                     7.0      7.0     13.0      6.0      7.0      7.0
# B-E                     5.0      4.0      9.0      6.0      6.0      9.0
# B-F                     6.0      5.0      7.0      7.0      5.0      6.0
# B-G                     3.0      4.0      5.0      3.0      2.0      5.0
# B-H                     2.0      3.0      1.0      2.0      3.0      3.0
# C-D                     4.0      9.0     11.0      7.0     12.0     12.0
# C-E                     4.0      2.0      6.0      6.0      3.0      3.0
# C-F                     5.0      6.0      6.0     11.0     10.0      8.0
# C-G                     2.0      2.0      4.0      4.0      5.0      3.0
# C-H                     2.0      4.0      3.0      4.0      3.0      3.0
# D-E                     5.0      8.0      8.0      7.0      5.0      8.0
# D-F                     4.0      6.0      7.0      5.0      6.0      4.0
# D-G                     9.0      7.0      6.0      9.0     12.0      7.0
# D-H                     3.0      1.0      2.0      2.0      2.0      2.0
# E-F                    13.0     10.0     13.0      8.0     12.0     12.0
# E-G                     5.0      4.0      7.0      9.0      7.0      9.0
# E-H                     3.0      4.0      4.0      3.0      4.0      3.0
# F-G                     6.0      6.0      7.0     10.0      8.0      8.0
# F-H                     6.0      9.0      5.0      5.0      8.0      5.0
# G-H                    15.0     15.0     12.0     11.0      7.0      8.0
#
#                     User #7  User #8  User #9  User #10  User #11  User #12  \
# Saccade Transition
# A-B                    19.0     11.0     14.0       7.0      16.0      18.0
# A-C                     4.0     14.0     14.0      10.0       5.0      13.0
# A-D                     4.0      6.0      3.0       6.0       2.0       4.0
# A-E                     7.0     10.0      6.0       9.0       8.0       6.0
# A-F                     2.0      3.0      3.0       2.0       1.0       3.0
# A-G                     2.0      2.0      2.0       2.0       1.0       1.0
# A-H                     3.0      6.0      6.0       6.0       6.0       2.0
# B-C                    17.0      4.0      6.0      19.0       4.0      12.0
# B-D                    13.0     10.0      4.0       8.0       9.0      13.0
# B-E                     4.0      4.0      4.0       4.0       6.0       8.0
# B-F                     7.0      6.0      6.0       5.0       8.0       7.0
# B-G                     4.0      2.0      4.0       3.0       6.0       6.0
# B-H                     5.0      5.0      1.0       1.0       1.0       2.0
# C-D                     9.0     13.0      9.0       5.0       4.0       7.0
# C-E                     4.0      5.0      4.0       2.0       6.0       2.0
# C-F                     6.0      5.0      7.0      10.0      11.0       3.0
# C-G                     4.0      4.0      2.0       6.0       4.0       5.0
# C-H                     1.0      2.0      1.0       2.0       3.0       4.0
# D-E                     7.0      6.0      4.0       6.0       8.0       4.0
# D-F                     2.0      7.0      5.0       5.0       5.0       3.0
# D-G                    12.0     12.0      9.0       9.0       5.0      12.0
# D-H                     1.0      3.0      2.0       1.0       2.0       3.0
# E-F                    13.0     12.0      8.0      10.0      10.0       9.0
# E-G                    10.0      5.0      8.0       8.0      10.0       4.0
# E-H                     2.0      3.0      1.0       3.0       2.0       1.0
# F-G                     6.0      8.0     11.0       7.0       6.0       8.0
# F-H                     5.0      9.0      8.0       8.0       5.0       9.0
# G-H                    14.0     13.0     15.0       9.0       4.0      14.0
#
#                     User #13  User #14  User #15  User #16  User #17  \
# Saccade Transition
# A-B                     16.0      10.0       9.0      18.0      10.0
# A-C                     13.0       8.0       6.0       5.0      12.0
# A-D                      2.0       5.0       8.0       2.0       7.0
# A-E                      8.0      10.0       7.0       6.0       7.0
# A-F                      2.0       3.0       3.0       1.0       3.0
# A-G                      2.0       2.0       2.0       2.0       1.0
# A-H                      4.0       3.0       4.0       4.0       2.0
# B-C                     17.0      14.0      19.0       7.0       4.0
# B-D                      7.0      14.0       4.0      11.0       6.0
# B-E                      4.0       4.0       5.0       4.0       5.0
# B-F                      8.0       5.0       7.0       6.0       7.0
# B-G                      6.0       6.0       4.0       6.0       2.0
# B-H                      4.0       5.0       1.0       2.0       2.0
# C-D                      9.0       7.0      13.0      13.0      10.0
# C-E                      2.0       6.0       5.0       5.0       4.0
# C-F                     11.0      11.0       5.0      12.0       6.0
# C-G                      2.0       2.0       3.0       2.0       2.0
# C-H                      2.0       3.0       1.0       4.0       1.0
# D-E                      5.0       7.0       4.0       4.0       8.0
# D-F                      2.0       5.0       2.0       7.0       5.0
# D-G                      6.0      10.0      12.0       6.0       8.0
# D-H                      2.0       3.0       1.0       3.0       3.0
# E-F                      9.0      10.0      14.0      13.0       9.0
# E-G                     10.0       5.0       9.0       5.0       4.0
# E-H                      1.0       3.0       2.0       1.0       3.0
# F-G                      7.0       8.0      12.0      12.0      12.0
# F-H                      8.0       5.0      11.0       9.0      10.0
# G-H                     10.0      10.0      13.0      16.0       9.0
#
#                     User #18  User #19  User #20
# Saccade Transition
# A-B                     19.0       9.0      17.0
# A-C                      4.0       9.0      14.0
# A-D                      3.0       7.0       5.0
# A-E                     10.0       7.0       9.0
# A-F                      2.0       1.0       1.0
# A-G                      1.0       1.0       2.0
# A-H                      4.0       6.0       6.0
# B-C                     11.0      12.0       8.0
# B-D                     14.0       7.0      14.0
# B-E                      3.0       9.0       9.0
# B-F                      8.0       7.0       7.0
# B-G                      5.0       2.0       4.0
# B-H                      1.0       1.0       4.0
# C-D                      5.0       9.0      10.0
# C-E                      6.0       3.0       5.0
# C-F                     10.0       4.0       9.0
# C-G                      6.0       5.0       1.0
# C-H                      2.0       3.0       2.0
# D-E                      5.0       6.0       6.0
# D-F                      3.0       5.0       3.0
# D-G                      9.0      11.0       9.0
# D-H                      3.0       2.0       2.0
# E-F                     10.0       9.0      12.0
# E-G                      4.0       5.0       4.0
# E-H                      1.0       1.0       1.0
# F-G                      9.0       8.0      12.0
# F-H                     11.0      10.0       6.0
# G-H                      8.0      12.0       5.0

# %%
sns.clustermap(df, metric="sqeuclidean", standard_scale=1, cmap="coolwarm")
#This output is the raw generation of the maximized variance, Squared Euclidean distance heatmap:

# %%
sns.clustermap(df, metric="euclidean", standard_scale=1, method="ward", cmap="coolwarm")
#This output is the raw generation of the minimized variance heatmap:

# %%
sns.clustermap(df, z_score=1, cmap="coolwarm")
#This output is the raw generation of the normalized heatmap:
