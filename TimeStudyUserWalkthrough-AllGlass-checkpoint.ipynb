# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Brandon\Desktop\Time Study Example Data Frames\WalkthroughData - AllGlass.csv", index_col=0)
df = df.iloc[0:14,0:8]
df
#The output below show all of the raw data that will be interpreting for generating a heirarchical clustering heatmap:
# Out:
#         User #1  User #3  User #5  User #7  User #9  User #11  User #13  \
# Task #
# 1        179.55   232.52    90.53    93.96   277.77    159.50    270.52
# 2a        13.08    37.58    18.72    28.66    43.89     25.51     27.10
# 2b         8.32    15.95    31.71    25.37    30.00     20.02     27.90
# 2c        29.41    25.20    16.38    30.43    30.35     14.80     19.38
# 2d        56.87    86.93    70.90    52.48    31.95     52.97     58.96
# 2e        55.99    48.79    35.85    42.51    35.71     45.15     52.08
# 2f        28.01    14.35    15.74    24.94    22.72     25.98     25.91
# 2g        16.18     5.07    15.80    11.48    16.95     19.83     16.20
# 2h        14.50    12.82    20.65    29.62    28.11     12.92     16.99
# 2i       130.69   174.50   103.97    83.73    62.45    118.47    128.42
# 2j       174.94    78.93    88.15    70.76   162.78    150.40    159.33
# 2k        28.59    41.08    27.89    32.82    59.24     23.19     28.74
# 2l        13.99    20.38    14.61    18.02    21.62     25.77     12.54
# 3         41.37    23.89    38.89    26.70    45.52     24.37     34.77
#
#         User #15
# Task #
# 1          90.99
# 2a         20.29
# 2b         12.47
# 2c         11.04
# 2d         50.42
# 2e         47.79
# 2f         12.25
# 2g          9.38
# 2h         22.58
# 2i         80.00
# 2j         73.23
# 2k         38.81
# 2l         16.51
# 3          42.45

# %%
lst = list(df.columns)
for x in range(len(lst)):
    df[lst[x]] = pd.to_numeric(df[lst[x]], downcast="float")
df
#The same as the previous output but datframe has been converted to float decimals:
# Out:
#            User #1     User #3     User #5    User #7     User #9    User #11  \
# Task #
# 1       179.550003  232.520004   90.529999  93.959999  277.769989  159.500000
# 2a       13.080000   37.580002   18.719999  28.660000   43.889999   25.510000
# 2b        8.320000   15.950000   31.709999  25.370001   30.000000   20.020000
# 2c       29.410000   25.200001   16.379999  30.430000   30.350000   14.800000
# 2d       56.869999   86.930000   70.900002  52.480000   31.950001   52.970001
# 2e       55.990002   48.790001   35.849998  42.509998   35.709999   45.150002
# 2f       28.010000   14.350000   15.740000  24.940001   22.719999   25.980000
# 2g       16.180000    5.070000   15.800000  11.480000   16.950001   19.830000
# 2h       14.500000   12.820000   20.650000  29.620001   28.110001   12.920000
# 2i      130.690002  174.500000  103.970001  83.730003   62.450001  118.470001
# 2j      174.940002   78.930000   88.150002  70.760002  162.779999  150.399994
# 2k       28.590000   41.080002   27.889999  32.820000   59.240002   23.190001
# 2l       13.990000   20.379999   14.610000  18.020000   21.620001   25.770000
# 3        41.369999   23.889999   38.889999  26.700001   45.520000   24.370001
#
#           User #13   User #15
# Task #
# 1       270.519989  90.989998
# 2a       27.100000  20.290001
# 2b       27.900000  12.470000
# 2c       19.379999  11.040000
# 2d       58.959999  50.419998
# 2e       52.080002  47.790001
# 2f       25.910000  12.250000
# 2g       16.200001   9.380000
# 2h       16.990000  22.580000
# 2i      128.419998  80.000000
# 2j      159.330002  73.230003
# 2k       28.740000  38.810001
# 2l       12.540000  16.510000
# 3        34.770000  42.450001

# %%
sns.clustermap(df, metric="sqeuclidean", standard_scale=1, cmap="coolwarm")
#This output is the raw generation of the maximized variance, Squared Euclidean distance heatmap:

# %%
sns.clustermap(df, metric="euclidean", standard_scale=1, method="ward", cmap="coolwarm")
#This output is the raw generation of the minimized variance heatmap:

# %%
sns.clustermap(df, z_score=1, cmap="coolwarm")
#This output is the raw generation of the normalized heatmap:
