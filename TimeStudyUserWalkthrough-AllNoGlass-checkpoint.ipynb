# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Brandon\Desktop\Time Study Example Data Frames\WalkthroughData - AllNoGlass.csv", index_col=0)
df = df.iloc[0:14,0:8]
df
#The output below show all of the raw data that will be interpreting for generating a heirarchical clustering heatmap:
# Out:
#         User #2  User #4  User #6  User #8  User #10  User #12  User #14  \
# Task #
# 1        161.69   181.24   127.52   128.21    166.21    102.86    164.46
# 2a        12.24    36.93    30.22    25.32     35.16     40.12     26.53
# 2b        17.55    31.44    18.08    11.40     11.35     28.72     13.21
# 2c        27.95    26.17    10.83    31.46     11.78     14.82     26.81
# 2d        86.85    85.13    67.15    69.42     87.56     32.42     49.05
# 2e        38.96    38.49    56.00    53.15     46.61     46.10     37.60
# 2f        13.61    11.49     8.79    25.66     13.03     15.42      8.74
# 2g        15.68     9.61    19.17    16.21     11.62     13.10     13.43
# 2h        22.63    14.63    15.97    19.83     16.22     22.25     19.35
# 2i       143.19   134.85   162.36    74.18    143.07    162.42    165.44
# 2j       174.85   158.67   137.81    98.10    157.56    121.40     94.42
# 2k        58.90    47.36    37.86    59.28     46.29     50.84     51.08
# 2l        22.28    10.88    23.84    13.69     17.25     28.17     14.10
# 3         52.66    58.52    31.66    31.81     58.20     56.58     53.90
#
#         User #16
# Task #
# 1         262.83
# 2a         15.25
# 2b         17.85
# 2c         11.38
# 2d         53.07
# 2e         38.30
# 2f         28.90
# 2g          4.30
# 2h         10.28
# 2i         68.80
# 2j        118.64
# 2k         23.07
# 2l         12.61
# 3          56.47

# %%
lst = list(df.columns)
for x in range(len(lst)):
    df[lst[x]] = pd.to_numeric(df[lst[x]], downcast="float")
df
#The same as the previous output but datframe has been converted to float decimals:
# Out:
#            User #2     User #4     User #6     User #8    User #10  \
# Task #
# 1       161.690002  181.240005  127.519997  128.210007  166.210007
# 2a       12.240000   36.930000   30.219999   25.320000   35.160000
# 2b       17.549999   31.440001   18.080000   11.400000   11.350000
# 2c       27.950001   26.170000   10.830000   31.459999   11.780000
# 2d       86.849998   85.129997   67.150002   69.419998   87.559998
# 2e       38.959999   38.490002   56.000000   53.150002   46.610001
# 2f       13.610000   11.490000    8.790000   25.660000   13.030000
# 2g       15.680000    9.610000   19.170000   16.209999   11.620000
# 2h       22.629999   14.630000   15.970000   19.830000   16.219999
# 2i      143.190002  134.850006  162.360001   74.180000  143.070007
# 2j      174.850006  158.669998  137.809998   98.099998  157.559998
# 2k       58.900002   47.360001   37.860001   59.279999   46.290001
# 2l       22.280001   10.880000   23.840000   13.690000   17.250000
# 3        52.660000   58.520000   31.660000   31.809999   58.200001
#
#           User #12    User #14    User #16
# Task #
# 1       102.860001  164.460007  262.829987
# 2a       40.119999   26.530001   15.250000
# 2b       28.719999   13.210000   17.850000
# 2c       14.820000   26.809999   11.380000
# 2d       32.419998   49.049999   53.070000
# 2e       46.099998   37.599998   38.299999
# 2f       15.420000    8.740000   28.900000
# 2g       13.100000   13.430000    4.300000
# 2h       22.250000   19.350000   10.280000
# 2i      162.419998  165.440002   68.800003
# 2j      121.400002   94.419998  118.639999
# 2k       50.840000   51.080002   23.070000
# 2l       28.170000   14.100000   12.610000
# 3        56.580002   53.900002   56.470001

# %%
sns.clustermap(df, metric="sqeuclidean", standard_scale=1, cmap="coolwarm")
#This output is the raw generation of the maximized variance, Squared Euclidean distance heatmap:

# %%
sns.clustermap(df, metric="euclidean", standard_scale=1, method="ward", cmap="coolwarm")
#This output is the raw generation of the minimized variance heatmap:

# %%
sns.clustermap(df, z_score=1, cmap="coolwarm")
#This output is the raw generation of the normalized heatmap:
